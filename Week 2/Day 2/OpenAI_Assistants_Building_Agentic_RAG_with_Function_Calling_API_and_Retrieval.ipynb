# %% [markdown]
# # OpenAI Assistants - Building Agentic RAG with the Function Calling, Retrieval, and Code Interpreter Tools
#
# Today we'll explore using OpenAI's Python SDK to create, manage, and use the OpenAI Assistant API!
#
# We'll be doing the following in today's notebook:
#
# 1. Task 1: Simple Assistant
# 2. Task 2: Adding Tools
#   - Task 2a: Creating an Assistant with File Search Tool
#   - Task 2b: Creating an Assistant with Code Interpreter Tool
#   - Task 2c: Creating an Assistant with Function Calling Tool
#
#
#
# ---
#
# Colab Specific Instructions:
#
# To get started, please make a copy of this notebook using `File > Save a copy in Drive`
#
# ![image](https://i.imgur.com/rNzMEfs.png)
#
# You will be expected to submit a GitHub link to the completed notebook, so if you're completing the assignment on Colab - you'll want to download the notebook when you have completed it.

# %% [markdown]
# ## Dependencies
#
# We'll start, as we usually do, with some dependiencies and our API key!

# %%
# !pip install -qU openai

# %%
from getpass import getpass
import os

os.environ["OPENAI_API_KEY"] = getpass("OpenAI API Key:")

# %% [markdown]
# ## Task 1: Simple Assistant
#
# Let's create a simple Assistant to understand more about how the API works to start!

# %% [markdown]
# ### OpenAI Client
#
# At the core of the OpenAI Python SDK is the Client!
#
# > NOTE: For ease of use, we'll start with the synchronous `OpenAI()`. OpenAI does provide an `AsyncOpenAI()` that you could leverage as well!

# %%
from openai import OpenAI

client = OpenAI()

# %% [markdown]
# ### Creating An Assistant
#
# Leveraging what we know about the OpenAI API from previous sessions - we're going to start by simply initializing an Assistant.
#
# Before we begin, we need to think about a few customization options we have:
#
# - `name` - Straight forward enough, this is what our Assistant's name will be
# - `instructions` - similar to a system message, but applied at an Assistant level, this is how we can guide the Assistant's tone, behaviour, functionality, and more!
# - `model` - this will allow us to choose which model we would prefer to use for our Assistant
#
# Let's start by setting some instructions for our Assistant.

# %%
# @markdown #### 🏗️ Build Activity 🏗️
# @markdown Fill out the fields below to add your Assistant's name, instructions, and desired model!

name = "CloudSecurity" # @param {type: "string"}
instructions = "you are a helpful agent that can answer questions about cloud security controls and issues. Your focus should be on three major providers namely AWS, Azure and GCP." # @param {type: "string"}
model = "gpt-4o" # @param ["gpt-3.5-turbo", "gpt-4-turbo-preview", "gpt-4", "gpt-4o"]

# %% [markdown]
# ### Initialize Assistant
#
# Now that we have our desired name, instruction, and model - we can initialize our Assistant!

# %%
assistant = client.beta.assistants.create(
    name=name,
    instructions=instructions,
    model=model,
)

# %% [markdown]
# Let's examine our `assistant` object and see what we find!

# %%
assistant
# Out:
# Assistant(id='asst_anTvMud4dWV3T51gEJWvYuPb', created_at=1717720694, description=None, instructions='you are a helpful agent that can answer questions about cloud security controls and issues. Your focus should be on three major providers namely AWS, Azure and GCP.', metadata={}, model='gpt-4o', name='CloudSecurity', object='assistant', tools=[], response_format='auto', temperature=1.0, tool_resources=ToolResources(code_interpreter=None, file_search=None), top_p=1.0)

# %% [markdown]
# There are a number of useful parameters here, but we'll call out a few:
#
# - `id` - since we may have multiple Assistant's, knowing which Assistant we're interacting with will help us ensure the desired user experience!
# - `description` - A natrual language description of our Assistant could help others understand what it's supposed to do!
# - `file_ids` - if we wanted to use the Retrieval tool, this would let us know what files we had given our Assistant

# %% [markdown]
# ### Creating a Thread
#
# Behind the scenes our Assistant is powered by the idea of "threads".
#
# You can think of threads as individual conversations that interact with the Assistant.
#
# Let's create a thread now!

# %%
thread = client.beta.threads.create()

# %% [markdown]
# Let's look at our `thread` object.

# %%
thread
# Out:
# Thread(id='thread_XJDW1thSrFOKqukSc9w30lJ5', created_at=1717712924, metadata={}, object='thread', tool_resources=ToolResources(code_interpreter=None, file_search=None))

# %% [markdown]
# Notice some key attributes:
#
# - `id` - since each Thread is like a conversation, we need some way to specify which thread we're dealing with when interacting with them
# - `tool_resources` - this will become more relevant as we add tools since we'll need a way to verify which tools we have access to when interacting with our Assistant

# %% [markdown]
# ### Adding Messages to Our Thread
#
# Now that we have our Thread (or conversation) we can start adding messages to it!
#
# Let's add a simple message that asks about how our Assistant is feeling.
#
# Notice the parameters we're leveraging:
#
# - `thread_id` - since each Thread is like a conversation, we need some way to address a specific conversation. We can use `thread.id` to do this.
# - `role` - similar to when we used our chat completions endpoint, this parameter specifies who the message is coming from. You can leverage this in the same ways you would through the chat completions endpoint.
# - `content` - this is where we can place the actual text our Assistant will interact with
#
# > NOTE: Feel free to substitute a relevant message based on the Assistant you created

# %%
message = client.beta.threads.messages.create(
    thread_id=thread.id,
    role="user",
    content=f"which cloud provider is more secure, AWS, Azure or GCP?"
)

# %% [markdown]
# Again, let's examine our `message` object!

# %%
message
# Out:
# Message(id='msg_qORtisGVpEf9kFdfCLzHepq7', assistant_id=None, attachments=[], completed_at=None, content=[TextContentBlock(text=Text(annotations=[], value='which cloud provider is more secure, AWS, Azure or GCP?'), type='text')], created_at=1717720773, incomplete_at=None, incomplete_details=None, metadata={}, object='thread.message', role='user', run_id=None, status=None, thread_id='thread_DUF4MsudNjNZyiSje5KJ6AoY')

# %% [markdown]
# ### Running Our Thread
#
# Now that we have an Assistant, and we've given that Assistant a Thread, and we've added a Message to that Thread - we're ready to run our Assistant!
#
# Notice that this process lets us add (potentially) multiple messages to our Assistant. We can leverage that behaviour for few/many-shot examples, and more!

# %%
# @markdown #### 🏗️ Build Activity 🏗️
# @markdown We can also override the Assistant's instructions when we run a thread.

# @markdown Use one of the [Prompt Principles for Instruction](https://arxiv.org/pdf/2312.16171v1.pdf) to improve the likeliehood of a correct or valuable response from your Assistant.

additional_instructions = "Also provide reason on why the one you responded as more secure than the other. " # @param {type: "string"}

# %% [markdown]
# Let's run our Thread!

# %%
run = client.beta.threads.runs.create(
  thread_id=thread.id,
  assistant_id=assistant.id,
  instructions=additional_instructions
)

# %% [markdown]
# Now that we've run our thread, let's look at the object!

# %%
run
# Out:
# Run(id='run_eaSgwqGkv4uWNhI0SxJMuAun', assistant_id='asst_anTvMud4dWV3T51gEJWvYuPb', cancelled_at=None, completed_at=None, created_at=1717720876, expires_at=1717721476, failed_at=None, incomplete_details=None, instructions='Also provide reason on why the one you responded as more secure than the other. ', last_error=None, max_completion_tokens=None, max_prompt_tokens=None, metadata={}, model='gpt-4o', object='thread.run', parallel_tool_calls=True, required_action=None, response_format='auto', started_at=None, status='queued', thread_id='thread_DUF4MsudNjNZyiSje5KJ6AoY', tool_choice='auto', tools=[], truncation_strategy=TruncationStrategy(type='auto', last_messages=None), usage=None, temperature=1.0, top_p=1.0, tool_resources={})

# %% [markdown]
# Notice we have access to a few very powerful parameters in this `run` object.
#
# - `completed_at` - this will help us determine when we can expect to retrieve a response
# - `failed_at` - this can highlight any issues our run ran into
# - `status` - is another way we can understand how the flow is going

# %% [markdown]
# ### Retrieving Our Run
#
# Now that we've created our run, let's retrieve it.
#
# We're going to wrap this in a simple loop to make sure we're not retrieving it too early.

# %%
import time

while run.status == "in_progress" or run.status == "queued":
  time.sleep(1)
  run = client.beta.threads.runs.retrieve(
    thread_id=thread.id,
    run_id=run.id
  )

# %%
print(run.status)
# Out:
# completed

# %% [markdown]
# Now that our run is completed - we can retieve the messages from our thread!
#
# Notice that our run helps us understand how things are going - but it isn't where we're going to find our responses or messages. Those are added on the backend into our thread.
#
# This leads to a simple, but important, flow:
#
# 1. We add messages to a thread.
# 2. We create a run on that thread.
# 3. We wait until the run is finished.
# 4. We check our thread for the new messages.

# %% [markdown]
# ### Checking Our Thread
#
# Now we can get a list of messages from our thread!

# %%
messages = client.beta.threads.messages.list(
  thread_id=thread.id
)

# %%
messages.data[0]
# Out:
# Message(id='msg_HY2QK4gQzKaAdsveUoiNI7Qt', assistant_id='asst_anTvMud4dWV3T51gEJWvYuPb', attachments=[], completed_at=None, content=[TextContentBlock(text=Text(annotations=[], value='Determining which cloud provider—AWS (Amazon Web Services), Azure (Microsoft Azure), or GCP (Google Cloud Platform)—is more secure can depend on several factors, including specific security needs, regulatory requirements, and the architecture of the solutions being deployed. However, all three providers are highly reputable and offer robust security measures. Here is a comparison based on some critical security aspects:\n\n### AWS (Amazon Web Services):\n1. **Robust Security Services**: AWS offers a broad range of security services, including AWS Identity and Access Management (IAM), AWS Key Management Service (KMS), AWS Shield, AWS CloudTrail, and AWS Security Hub.\n2. **Compliance**: AWS meets numerous compliance standards such as ISO 27001, SOC 1/2/3, PCI-DSS, HIPAA, and GDPR. AWS also provides a shared responsibility model and numerous compliance reports and resources.\n3. **Innovation and Tools**: AWS is known for continuously developing and releasing cutting-edge security tools and services. For instance, AWS provides GuardDuty for threat detection and Macie for data loss prevention.\n\n### Azure (Microsoft Azure):\n1. **Advanced Threat Protection**: Azure offers services such as Microsoft Defender for Cloud (previously Azure Security Center) for threat management and security monitoring, and Azure Sentinel, a scalable, cloud-native SIEM and SOAR solution.\n2. **Compliance and Certifications**: Azure complies with various global standards and certifications like ISO 27001, SOC 1/2/3, GDPR, HIPAA, and FedRAMP. Microsoft\'s compliance resources and Trust Center are comprehensive and thorough.\n3. **Security Integration**: Azure benefits from its integration with other Microsoft products, which can be advantageous for organizations already using Windows Server, Active Directory, or other Microsoft services.\n\n### GCP (Google Cloud Platform):\n1. **Security Features**: GCP emphasizes security with features such as Google Cloud IAM, Cloud Security Command Center, Google Cloud Armor, and VPC Service Controls. GCP is particularly strong in network security and data encryption.\n2. **Compliance and Certifications**: GCP adheres to a variety of international standards including ISO 27001, SOC 1/2/3, PCI DSS, FedRAMP, and GDPR. Google\'s Security and Privacy practices are considered highly rigorous.\n3. **Security Culture and Practices**: Google’s security model includes years of experience in managing security threats, given their vast global infrastructure and data centers. They also employ advanced techniques in machine learning for threat detection.\n\n### Conclusion:\nIn terms of security, AWS, Azure, and GCP are all robust and highly secure platforms. Each has its strengths and areas in which they excel:\n\n1. **AWS**: Known for a comprehensive suite of tools and services, aiming at flexibility and innovation in security.\n2. **Azure**: Leveraging Microsoft\'s ecosystem, Azure offers excellent security when integrated with other Microsoft tools and systems.\n3. **GCP**: Strong in network security and data encryption, GCP benefits from Google’s global infrastructure and expertise in data security.\n\n### Which One is More Secure?\n**There is no definitive "most secure" provider**—it largely depends on your particular use case, existing infrastructure, and security requirements. All three cloud providers are industry leaders with meticulous attention to security standards and practices.\n\n### Recommendation:\n- **Assess your specific security needs**: Determine which provider aligns best with the compliance requirements and security features critical to your business.\n- **Evaluate existing ecosystem**: Consider how well the cloud provider integrates with your other tools and systems.\n- **Leverage native tools**: Use the security tools and serv ...

# %% [markdown]
# ### Streaming Our Runs
#
# With recent upgrades to the Assistant API - we can now *stream* our outputs!
#
# In order to do this - we'll need something called an `EventHandler` which will help us to decide on what actions to take based on the output of the LLM.
#
# Let's build it below!

# %%
from typing_extensions import override
from openai import AssistantEventHandler

class EventHandler(AssistantEventHandler):
  @override
  def on_text_created(self, text) -> None:
    print(f"\nassistant > ", end="", flush=True)

  @override
  def on_text_delta(self, delta, snapshot):
    print(delta.value, end="", flush=True)

# %% [markdown]
# Now we can create our `run` and stream the output as it comes in!

# %%
with client.beta.threads.runs.stream(
  thread_id=thread.id,
  assistant_id=assistant.id,
  instructions=additional_instructions,
  event_handler=EventHandler(),
) as stream:
  stream.until_done()
# Out:
# assistant > To further assist in your decision-making process, it's important to address some additional nuances and industry perceptions regarding security in AWS, Azure, and GCP. Here are some insights into each provider’s security posture in more detail:
#
# ### AWS (Amazon Web Services):
# - **Track Record and Market Leadership**: AWS has been in the cloud market the longest and is often seen as the most mature cloud provider, with an extensive range of security policies and tools. AWS is proactive in updating and enhancing its security features, which is a testament to its commitment to secure cloud services.
# - **Customized Secure Environments**: The flexibility that AWS provides can be beneficial for organizations needing to build highly customized security environments. However, this flexibility requires users to understand and correctly configure security settings thoroughly, which means the platform is only as secure as the use case implemented.
#
# ### Azure (Microsoft Azure):
# - **Microsoft's Enterprise Expertise**: Azure benefits from Microsoft's extensive enterprise experience and their close alignment with large organizations, especially those already invested in the Microsoft ecosystem. Azure's integration with Active Directory and other Microsoft services might make it easier to implement cohesive security policies across hybrid environments.
# - **Unified Security Approach**: Azure provides a unified approach to security management through tools like Microsoft Defender for Cloud which gives visibility into the security posture of Azure assets and even on-premises and other cloud (AWS and GCP) resources.
#
# ### GCP (Google Cloud Platform):
# - **Security by Design**: Google’s history and expertise in dealing with vast amounts of data (particularly considering products like Search and YouTube) translate into a strong security-first culture. Google's zero-trust approach, which means treating the network as always potentially hostile, is embedded in GCP's security design.
# - **Data Protection**: Google's strong encryption practices, both at rest and in transit, are often highlighted as a significant advantage. Google’s infrastructure design includes encryption as a key component of its security strategy.
#
# ### User Perspective:
# - **Skill and Expertise**: The security of the cloud environment also significantly depends on the user's expertise in configuring and managing the cloud infrastructure. Misconfigurations remain one of the most common causes of cloud security breaches. For instance, a misconfigured AWS S3 bucket can lead to data exposure if not set up correctly.
# - **Managed Services**: Each provider offers managed security services, but their efficacy depends on how they are integrated and used by the organization. Engaging with managed security services or third-party security consultants can also help enhance the security posture across any of these cloud providers.
#
# ### Conclusion:
# For more security-conscious enterprises, known operational practices, and the ability to configure and control environments are essential. AWS, with its comprehensive suite of services and extensive security documentation, is often seen as the leader in this space. Azure's tight integration with Microsoft's ecosystem makes it highly attractive for enterprises heavily invested in Microsoft-based environments. GCP's robust encryption and strong security culture rooted in Google's engineering practices make it a formidable option.
#
# ### Recommendation:
# 1. **Conduct a Security Assessment**: Perform an in-depth security assessment of your requirements and how each cloud provider meets these requirements.
# 2. **Leverage Provider Expertise**: Use the specific strengths of each provider. For instance, enterprises might use GCP for highly secure data analytics, AWS for flexible, scalable infrastructure, and Azure for integrated enterprise solutions.
# 3. **Keep Updated**: Security is a continuous process. Regularly update and adjust your security practices to adapt to new threats and advancements in cloud security offered by your chosen provider.
#
# Choosing the right cloud provider will largely depend on how their security strengths align with your organization's specific needs, capabilities, and existing infrastructure.

# %% [markdown]
# ## Task 2: Adding Tools
#
# Now that we have an understanding of how Assistant works, we can start thinking about adding tools.
#
# We'll go through 3 separate tools and explore how we can leverage them!
#
# Let's start with the most familiar tool - the Retriever!

# %% [markdown]
# ### Task 2a: Creating an Assistant with the File Search Tool
#
# The first thing we'll want to do is create an assistant with the File Search tool.
#
# This is also going to require some data. We'll provided data - but you're very much encouraged to use your own files to explore how the Assistant works for your use case.

# %% [markdown]
# #### Collect and Add Data to Vector Store
#
# 1. First, we need some data.
# 2. Second, we need to add the data to our Assistant!
#
# Let's start with grabbing some data!

# %%
# !wget https://github.com/dbredvick/paul-graham-to-kindle/blob/main/paul_graham_essays.txt
# Out:
# --2024-06-06 17:44:31--  https://github.com/dbredvick/paul-graham-to-kindle/blob/main/paul_graham_essays.txt
# Resolving github.com (github.com)... 140.82.116.3
# Connecting to github.com (github.com)|140.82.116.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘paul_graham_essays.txt’
#
# paul_graham_essays.     [ <=>                ] 266.46K  --.-KB/s    in 0.1s
#
# 2024-06-06 17:44:32 (1.83 MB/s) - ‘paul_graham_essays.txt’ saved [272853]

# %% [markdown]
# Now we can upload our file to our Vector Store!
#
# Pay attention to [this](https://platform.openai.com/docs/assistants/tools/file-search/supported-files) documentation to see what kinds of files can be uploaded.
#
# > NOTE: Per the OpenAI [docs](https://platform.openai.com/docs/assistants/tools/file-search/vector-stores) The maximum file size is 512 MB and no more than 2,000,000 tokens (computed automatically when you attach a file)

# %%
vector_store = client.beta.vector_stores.create(name="Paul Graham Essay Compilation")

# %%
file_paths = ["paul_graham_essays.txt"]
file_streams = [open(path, "rb") for path in file_paths]

file_batch = client.beta.vector_stores.file_batches.upload_and_poll(
  vector_store_id=vector_store.id, files=file_streams
)

# %% [markdown]
# Let's look at what our `file_batch` contains!

# %%
while file_batch.status != "completed":
  time(1)

# %% [markdown]
# #### Create and Use Assistant
#
# Now that we have our file - we can attach it to an Assistant, and we can give that Assistant the ability to use it for retrieval through the Retrieval tool!
#
# > NOTE: Your first GB is free and beyond that, usage is billed at $0.10/GB/day of vector storage. There are no other costs associated with vector store operations.

# %%
fs_assistant = client.beta.assistants.create(
  name=name,
  instructions=instructions,
  model=model,
  tools=[{"type": "file_search"}],
)

# %%
fs_assistant = client.beta.assistants.update(
  assistant_id=fs_assistant.id,
  tool_resources={"file_search": {"vector_store_ids": [vector_store.id]}},
)

# %%
fs_thread = client.beta.threads.create(
  messages=[
    {
      "role": "user",
      "content": "What did Paul Graham say about Silicon Valley?",
    }
  ]
)

# %% [markdown]
# We can use an extension of the `EventHandler` that we created above to stream our `run`!
#
# Let's add a few things:
#
# 1. A `on_tool_call_created` function which tells us which tool is being used.
# 2. A `on_message_done` that includes citations that were used by our File Search tool - this is like return the context *and* the response that we saw in our Pythonic RAG implementation.

# %%
class FSEventHandler(AssistantEventHandler):
  @override
  def on_text_created(self, text) -> None:
    print(f"\nassistant > ", end="", flush=True)

  @override
  def on_tool_call_created(self, tool_call):
    print(f"\nassistant > {tool_call.type}\n", flush=True)

  @override
  def on_message_done(self, message) -> None:
    message_content = message.content[0].text
    annotations = message_content.annotations
    citations = []
    for index, annotation in enumerate(annotations):
      message_content.value = message_content.value.replace(
        annotation.text, f"[{index}]"
      )
      if file_citation := getattr(annotation, "file_citation", None):
        cited_file = client.files.retrieve(file_citation.file_id)
        citations.append(f"[{index}] {cited_file.filename}")

    print(message_content.value)
    print("\n".join(citations))

# %% [markdown]
# Let's look at the final result!

# %%
with client.beta.threads.runs.stream(
  thread_id=fs_thread.id,
  assistant_id=fs_assistant.id,
  event_handler=FSEventHandler(),
) as stream:
  stream.until_done()
# Out:
# assistant > file_search
#
#
# assistant > Paul Graham elaborates on the unique advantages of Silicon Valley's ecosystem in fostering startups. Key elements contributing to its success include:
#
# 1. **Concentration of Talent**: Silicon Valley attracts a high concentration of technical talent, which is crucial for technology-driven startups.
# 2. **Culture of Risk-Taking**: The region has a culture that encourages risk-taking and tolerates failure, allowing entrepreneurs to innovate without fear of stigma if they fail.
# 3. **Access to Capital**: The presence of a large number of venture capitalists ensures access to funding for startups.
# 4. **Network Effect**: The success of previous startups creates a network that supports and encourages new endeavors, leading to a self-reinforcing cycle of innovation .

# %% [markdown]
# ### Task 2b: Creating an Assistant with the Code Interpreter Tool
#
# Now that we've explored the Retrieval Tool - let's try the Code Interpreter tool!
#
# The process will be almost exactly the same - but we can explore a different query, and we'll add our file at the Message level!

# %%
ci_assistant = client.beta.assistants.create(
  name=name + "+ Code Interpreter",
  instructions=instructions,
  model=model,
  tools=[{"type": "code_interpreter"}],
)

# %%
# !git clone https://github.com/ali-ce/datasets.git
# Out:
# Cloning into 'datasets'...
# remote: Enumerating objects: 803, done.
# remote: Total 803 (delta 0), reused 0 (delta 0), pack-reused 803
# Receiving objects: 100% (803/803), 4.31 MiB | 11.96 MiB/s, done.
# Resolving deltas: 100% (336/336), done.

# %%
file = client.files.create(
  file=open("datasets/Y-Combinator/Startups.csv", "rb"),
  purpose='assistants'
)

# %% [markdown]
# In the following example, we'll also see how we can package the Thread creation with the Message adding step!
#
# > NOTE: Files added at the message/thread level will not be available to the Assistant outside of that Thread.

# %%
ci_thread = client.beta.threads.create(
  messages=[
    {
      "role": "user",
      "content": "What kind of file is this?",
      "attachments": [
          {
              "file_id" : file.id,
              "tools" : [{"type" : "code_interpreter"}]
          }
      ]
    }
  ]
)

# %% [markdown]
# We'll once again need to create an `EventHandler`, except this time it will have an `on_tool_call_delta` method which will let us see the output of the code interpreter tool as well!
#
# > NOTE: Remember that we create runs at the *thread* level - and so don't need the message object to continue.

# %%
class CIEventHandler(AssistantEventHandler):
  @override
  def on_text_created(self, text) -> None:
    print(f"\nassistant > ", end="", flush=True)

  @override
  def on_text_delta(self, delta, snapshot):
    print(delta.value, end="", flush=True)

  def on_tool_call_created(self, tool_call):
    print(f"\nassistant > {tool_call.type}\n", flush=True)

  def on_tool_call_delta(self, delta, snapshot):
    if delta.type == 'code_interpreter':
      if delta.code_interpreter.input:
        print(delta.code_interpreter.input, end="", flush=True)
      if delta.code_interpreter.outputs:
        print(f"\n\noutput >", flush=True)
        for output in delta.code_interpreter.outputs:
          if output.type == "logs":
            print(f"\n{output.logs}", flush=True)

# %% [markdown]
# Once again, we can use the streaming interface thanks to creating our `EventHandler`!

# %%
with client.beta.threads.runs.stream(
  thread_id=ci_thread.id,
  assistant_id=ci_assistant.id,
  instructions=additional_instructions,
  event_handler=CIEventHandler(),
) as stream:
  stream.until_done()
# Out:
# assistant > code_interpreter
#
# import magic
#
# file_path = '/mnt/data/file-G4dpd5Fr1t51pYBA3E16ouIR'
#
# # Use the magic library to detect the file type
# file_type = magic.from_file(file_path)
#
# file_typeimport mimetypes
#
# # Use mimetypes to guess the file type
# file_type, _ = mimetypes.guess_type(file_path)
#
# file_typeimport mimetypes
#
# file_path = '/mnt/data/file-G4dpd5Fr1t51pYBA3E16ouIR'
#
# # Use mimetypes to guess the file type
# file_type, _ = mimetypes.guess_type(file_path)
#
# file_type
# assistant > The `mimetypes` library was unable to determine the file type. Let's inspect the file to get a hint about its type.# Open the file and read a few bytes to inspect its contents
# file_path = '/mnt/data/file-G4dpd5Fr1t51pYBA3E16ouIR'
#
# with open(file_path, 'rb') as file:
#     file_header = file.read(20)
#
# file_header
# assistant > The content of the file starts with the text `Company,Status,Year F`, which suggests that it is likely a CSV (Comma-Separated Values) file. CSV files typically start with headers that describe the columns of the data.
#
# Let's confirm the content by reading the entire file.# Read the entire file to confirm its contents
# with open(file_path, 'r') as file:
#     contents = file.read()
#
# contents
# assistant > The file is indeed a CSV (Comma-Separated Values) file containing various data, such as company names, statuses, locations, descriptions, founders, and financial information.
#
# If you need to perform further analysis or extract specific information from this file, please let me know!

# %% [markdown]
# And there you go!
#
# We've fit our Assistant with an awesome Code Interpreter that lets our Assistant run code on our provided files!

# %% [markdown]
# ### Task 2c: Creating an Assistant with a Function Calling Tool
#
# Let's finally create an Assistant that utilizes the Function Calling API.
#
# We'll start by creating a function that we wish to be called.
#
# We'll utilize DuckDuckGo search to allow our Assistant to have the most up to date information!

# %%
# !pip install -qU duckduckgo_search

# %%
from duckduckgo_search import DDGS

def duckduckgo_search(query):
  with DDGS() as ddgs:
    results = [r for r in ddgs.text(query, max_results=5)]
    return "\n".join(result["body"] for result in results)

# %% [markdown]
# Let's test our function to make sure it behaves as we expect it to.

# %%
duckduckgo_search("in which year were the three cloud providers AWS, Azure and GCP founded?")
# Out:
# "Now, one thing to note when comparing cloud providers with regard to revenue is that their reporting groupings are not the same. Amazon reports AWS revenue separately, while Google includes both GCP and their Workplace product as part of their cloud revenue. Microsoft bundles Azure, on-prem server software, Visual Studio, and GitHub into their ...\nDominating the Cloud Service Provider (CSP) market are three hyperscalers: Amazon Web Services (AWS) , Microsoft Azure , and Google Cloud Platform (GCP) . They consume an impressive 34%, 21%, and 10% respectively of the global cloud infrastructure market (as at June 2022), which is worth a staggering $203 billion.\nThe cloud computing market continues to grow, and is projected to reach $2432.87 billion by 2030. In this massive market, three cloud providers—Amazon Web Services (AWS), Google Cloud Platform (GCP), and Microsoft Azure—make up a combined 64% of the cloud market share, and when choosing a cloud provider to host their website or application, many users will choose between these three ...\nAmazon Web Services (AWS), Microsoft Azure, and Google Cloud Platform (GCP) combined to make up 64 percent of the global cloud market in 2021, making them the clear power players of the industry. Although there are many other established providers who offer an outstanding array of services, such as Alibaba Cloud, IBM Cloud, and Oracle Cloud ...\nWe've compiled a summary cloud services comparison of Amazon Web Service (AWS), Microsoft Azure, and Google Cloud Platform (GCP) to help inform you in your multi-cloud journey. Whether your organization is looking to adopt a multi-cloud model or working to perfect your existing multi-cloud strategy, understanding the range of services offered ..."

# %% [markdown]
# Now we need to express how our function works in a way that is compatible with the OpenAI Function Calling API.
#
# We'll want to provide a `JSON` object that includes what parameters we have, how to call them, and a short natural language description.

# %%
ddg_function = {
    "name" : "duckduckgo_search",
    "description" : "Answer non-technical questions. ",
    "parameters" : {
        "type" : "object",
        "properties" : {
            "query" : {
                "type:" : "string",
                "description" : "The search query to use. For example: 'Who is the current Goalie of the Colorado Avalance?'"
            }
        },
        "required" : ["query"]
    }
}

# %% [markdown]
# ####❓ Question
#
# Why does the description key-value pair matter?

# %% [markdown]
# Now when we create our Assistant - we'll want to include the function description as a tool using the following format.

# %%
fc_assistant = client.beta.assistants.create(
    name=name + " + Function Calling",
    instructions=instructions,
    tools=[
        {"type": "function",
         "function" : ddg_function
        }
    ],
    model=model
)

# %% [markdown]
# Now we can create our thread, and attach our message to it - just as we've been doing!

# %%
fc_thread = client.beta.threads.create()
fc_message = client.beta.threads.messages.create(
  thread_id=fc_thread.id,
  role="user",
  content="Can you show the last 5 tweets from the user @abhinavbom",
)

# %% [markdown]
# Once again, we'll need an `EventHandler` for the streaming response - notice that this time we're utilizing a few new methods:
#
# 1. `handle_requires_action` - this will handle whatever action needs to take place in *our local environment*.
# 2. `submit_tool_outputs` - this will let us submit the resultant outputs from our local function call back to the Assistant run in the required format.
#
# To be very clear and explicit - we'll be following this pattern:
#
# 1. Make a call to the LLM which will decide if a local function call is required.
# 2. If a local function call is required - send a response that indicates a local function call is required.
# 3. Call the function using the arguments provided by the LLM.
# 4. Return the response from the function call with LLM provided arguements.
# 5. Receive a response based on the output of the functional call from the LLM.

# %%
class FCEventHandler(AssistantEventHandler):
  @override
  def on_event(self, event):
    # Retrieve events that are denoted with 'requires_action'
    # since these will have our tool_calls
    if event.event == 'thread.run.requires_action':
      run_id = event.data.id  # Retrieve the run ID from the event data
      self.handle_requires_action(event.data, run_id)

  def handle_requires_action(self, data, run_id):
    tool_outputs = []

    for tool in data.required_action.submit_tool_outputs.tool_calls:
      print(tool.function.arguments)
      if tool.function.name == "duckduckgo_search":
        tool_outputs.append({"tool_call_id": tool.id, "output": duckduckgo_search(tool.function.arguments)})

    # Submit all tool_outputs at the same time
    self.submit_tool_outputs(tool_outputs, run_id)

  def submit_tool_outputs(self, tool_outputs, run_id):
    # Use the submit_tool_outputs_stream helper
    with client.beta.threads.runs.submit_tool_outputs_stream(
      thread_id=self.current_run.thread_id,
      run_id=self.current_run.id,
      tool_outputs=tool_outputs,
      event_handler=EventHandler(),
    ) as stream:
      for text in stream.text_deltas:
        print(text, end="", flush=True)
      print()

# %% [markdown]
# Thanks to our event handler - we can stream this process in our notebook!

# %%
with client.beta.threads.runs.stream(
  thread_id=fc_thread.id,
  assistant_id=fc_assistant.id,
  event_handler=FCEventHandler()
) as stream:
  stream.until_done()
# Out:
# {"query":"@abhinavbom latest tweets"}
#
# assistant > I'mI'm currently currently unable unable to to access access live live Twitter Twitter data data.. To To view view the the latest latest tweets tweets from from the the user user @ @ababhinhinavavbombom,, you you can can visit visit their their [ [TwitterTwitter profile profile](](httpshttps://://twittertwitter.com.com//ababhinhinavavbombom).).
